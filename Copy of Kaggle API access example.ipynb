# %%
# Run this cell and select the kaggle.json file downloaded
# from the Kaggle account settings page.
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-e8b22c65-685b-4399-a4ca-21fab14dfbb9" name="files[]" multiple disabled />
#      <output id="result-e8b22c65-685b-4399-a4ca-21fab14dfbb9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# {}

# %%
# Let's make sure the kaggle.json file is present.
# !ls -lha kaggle.json
# Out:
# ls: cannot access 'kaggle.json': No such file or directory

# %%
# Next, install the Kaggle API client.
# !pip install -q kaggle

# %%
# The Kaggle API client expects this file to be in ~/.kaggle,
# so move it there.
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# This permissions change avoids a warning on Kaggle tool startup.
# !chmod 600 ~/.kaggle/kaggle.json

# !ls -l ~/.kaggle
# !cat ~/.kaggle/kaggle.json
# Out:
# total 4
# -rw------- 1 root root 70 Oct 28 15:28 kaggle.json
# {"username":"varshasachdeva","key":"fd1c4ae9c2c342ab411620583f46f0ef"}

# %%
# !pip install -q kaggle
# !pip install -q kaggle-cli
# Out:
#      |████████████████████████████████| 81kB 2.6MB/s
#      |████████████████████████████████| 5.3MB 8.3MB/s
#      |████████████████████████████████| 112kB 52.5MB/s
#      |████████████████████████████████| 112kB 48.8MB/s
#      |████████████████████████████████| 51kB 6.3MB/s
#   Building wheel for kaggle-cli (setup.py) ... done
#   Building wheel for pyperclip (setup.py) ... done

# %%
# !kaggle datasets list
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.6 / client 1.5.4)
# ref                                                      title                                               size  lastUpdated          downloadCount
# -------------------------------------------------------  -------------------------------------------------  -----  -------------------  -------------
# tristan581/17k-apple-app-store-strategy-games            17K Mobile Strategy Games                            8MB  2019-08-26 08:22:16           7641
# gustavomodelli/forest-fires-in-brazil                    Forest Fires in Brazil                              31KB  2019-08-24 16:09:16           8714
# akhilv11/border-crossing-entry-data                      Border Crossing Entry Data                           3MB  2019-08-21 14:51:34           3562
# rajeevw/ufcdata                                          UFC-Fight historical data from 1993 to 2019          3MB  2019-07-05 09:58:02           4711
# shuyangli94/food-com-recipes-and-user-interactions       Food.com Recipes and Interactions                  261MB  2019-10-12 06:30:37           2583
# chirin/africa-economic-banking-and-systemic-crisis-data  Africa Economic, Banking and Systemic Crisis Data   14KB  2019-07-21 02:00:17           2840
# ruslankl/european-union-lgbt-survey-2012                 EU LGBT Survey                                     610KB  2019-07-19 11:15:25           1319
# kapilverma/hindi-bible                                   Hindi Bible                                          4MB  2019-09-07 18:04:35            258
# hmavrodiev/sofia-air-quality-dataset                     Sofia air quality dataset                            3GB  2019-09-14 05:48:09            920
# brkurzawa/us-breweries                                   US Breweries                                        76KB  2019-10-02 03:15:27            983
# jojoker/singapore-airbnb                                 Singapore Airbnb                                   350KB  2019-09-25 22:05:44           1169
# srikantsahu/co2-and-ghg-emission-data                    CO2 and GHG emission data                           91KB  2019-09-26 20:10:59           1008
# pascalbliem/european-social-survey-ess-8-ed21-201617     European Social Survey (ESS) 8 ed2.1 (2016/17)      10MB  2019-09-29 07:30:37            369
# grikomsn/amazon-cell-phones-reviews                      Amazon Cell Phones Reviews                          10MB  2019-09-29 02:26:48           1326
# irinachuchueva/russian-wholesale-electricity-market      Russian Wholesale Electricity Market                 1MB  2019-10-09 08:20:57            339
# smid80/canadian-federal-election-results-timeseries      Canadian Federal Election Results (Timeseries)      18MB  2019-10-09 11:08:29            335
# hmavrodiev/london-bike-sharing-dataset                   London bike sharing dataset                        165KB  2019-10-10 12:49:37           1596
# nitinsss/military-expenditure-of-countries-19602019      Military Spending of Countries (1960-2019)          55KB  2019-10-10 12:17:37           1573
# mabusalah/brent-oil-prices                               Brent Oil Prices                                    38KB  2019-10-14 12:31:05            867
# valentynsichkar/traffic-signs-preprocessed               Traffic Signs Preprocessed                            0B  2019-08-31 18:22:11            870

# %%
import numpy as np
from google.colab import drive
drive.mount('/content/drive/')
import os
#os.path.exists('/content/src/')
os.chdir('/content/drive/My Drive/')
currentDirectory = os.getcwd()
print(currentDirectory)


# Copy the stackoverflow data set locally.
# !kaggle datasets download -d mondejar/mitbih-database
# Out:
# Mounted at /content/drive/
# /content/drive/My Drive
# mitbih-database.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !mkdir mit_dataset
# !unzip \mitbih-database.zip -d mit_dataset
# Out:
# Archive:  mitbih-database.zip
#   inflating: mit_dataset/100.csv
#   inflating: mit_dataset/100annotations.txt
#   inflating: mit_dataset/101.csv
#   inflating: mit_dataset/101annotations.txt
#   inflating: mit_dataset/102.csv
#   inflating: mit_dataset/102annotations.txt
#   inflating: mit_dataset/103.csv
#   inflating: mit_dataset/103annotations.txt
#   inflating: mit_dataset/104.csv
#   inflating: mit_dataset/104annotations.txt
#   inflating: mit_dataset/105.csv
#   inflating: mit_dataset/105annotations.txt
#   inflating: mit_dataset/106.csv
#   inflating: mit_dataset/106annotations.txt
#   inflating: mit_dataset/107.csv
#   inflating: mit_dataset/107annotations.txt
#   inflating: mit_dataset/108.csv
#   inflating: mit_dataset/108annotations.txt
#   inflating: mit_dataset/109.csv
#   inflating: mit_dataset/109annotations.txt
#   inflating: mit_dataset/111.csv
#   inflating: mit_dataset/111annotations.txt
#   inflating: mit_dataset/112.csv
#   inflating: mit_dataset/112annotations.txt
#   inflating: mit_dataset/113.csv
#   inflating: mit_dataset/113annotations.txt
#   inflating: mit_dataset/114.csv
#   inflating: mit_dataset/114annotations.txt
#   inflating: mit_dataset/115.csv
#   inflating: mit_dataset/115annotations.txt
#   inflating: mit_dataset/116.csv
#   inflating: mit_dataset/116annotations.txt
#   inflating: mit_dataset/117.csv
#   inflating: mit_dataset/117annotations.txt
#   inflating: mit_dataset/118.csv
#   inflating: mit_dataset/118annotations.txt
#   inflating: mit_dataset/119.csv
#   inflating: mit_dataset/119annotations.txt
#   inflating: mit_dataset/121.csv
#   inflating: mit_dataset/121annotations.txt
#   inflating: mit_dataset/122.csv
#   inflating: mit_dataset/122annotations.txt
#   inflating: mit_dataset/123.csv
#   inflating: mit_dataset/123annotations.txt
#   inflating: mit_dataset/124.csv
#   inflating: mit_dataset/124annotations.txt
#   inflating: mit_dataset/200.csv
#   inflating: mit_dataset/200annotations.txt
#   inflating: mit_dataset/201.csv
#   inflating: mit_dataset/201annotations.txt
#   inflating: mit_dataset/202.csv
#   inflating: mit_dataset/202annotations.txt
#   inflating: mit_dataset/203.csv
#   inflating: mit_dataset/203annotations.txt
#   inflating: mit_dataset/205.csv
#   inflating: mit_dataset/205annotations.txt
#   inflating: mit_dataset/207.csv
#   inflating: mit_dataset/207annotations.txt
#   inflating: mit_dataset/208.csv
#   inflating: mit_dataset/208annotations.txt
#   inflating: mit_dataset/209.csv
#   inflating: mit_dataset/209annotations.txt
#   inflating: mit_dataset/210.csv
#   inflating: mit_dataset/210annotations.txt
#   inflating: mit_dataset/212.csv
#   inflating: mit_dataset/212annotations.txt
#   inflating: mit_dataset/213.csv
#   inflating: mit_dataset/213annotations.txt
#   inflating: mit_dataset/214.csv
#   inflating: mit_dataset/214annotations.txt
#   inflating: mit_dataset/215.csv
#   inflating: mit_dataset/215annotations.txt
#   inflating: mit_dataset/217.csv
#   inflating: mit_dataset/217annotations.txt
#   inflating: mit_dataset/219.csv
#   inflating: mit_dataset/219annotations.txt
#   inflating: mit_dataset/220.csv
#   inflating: mit_dataset/220annotations.txt
#   inflating: mit_dataset/221.csv
#   inflating: mit_dataset/221annotations.txt
#   inflating: mit_dataset/222.csv
#   inflating: mit_dataset/222annotations.txt
#   inflating: mit_dataset/223.csv
#   inflating: mit_dataset/223annotations.txt
#   inflating: mit_dataset/228.csv
#   inflating: mit_dataset/228annotations.txt
#   inflating: mit_dataset/230.csv
#   inflating: mit_dataset/230annotations.txt
#   inflating: mit_dataset/231.csv
#   inflating: mit_dataset/231annotations.txt
#   inflating: mit_dataset/232.csv
#   inflating: mit_dataset/232annotations.txt
#   inflating: mit_dataset/233.csv
#   inflating: mit_dataset/233annotations.txt
#   inflating: mit_dataset/234.csv
#   inflating: mit_dataset/234annotations.txt
#   inflating: mit_dataset/mitbih_database/100.csv
#   inflating: mit_dataset/mitbih_database/100annotations.txt
#   inflating: mit_dataset/mitbih_database/101.csv
#   inflating: mit_dataset/mitbih_database/101annotations.txt
#   inflating: mit_dataset/mitbih_database/102.csv
#   inflating: mit_dataset/mitbih_database/102annotations.txt
#   inflating: mit_dataset/mitbih_database/103.csv
#   inflating: mit_dataset/mitbih_database/103annotations.txt
#   inflating: mit_dataset/mitbih_database/104.csv
#   inflating: mit_dataset/mitbih_database/104annotations.txt
#   inflating: mit_dataset/mitbih_database/105.csv
#   inflating: mit_dataset/mitbih_database/105annotations.txt
#   inflating: mit_dataset/mitbih_database/106.csv
#   inflating: mit_dataset/mitbih_database/106annotations.txt
#   inflating: mit_dataset/mitbih_database/107.csv
#   inflating: mit_dataset/mitbih_database/107annotations.txt
#   inflating: mit_dataset/mitbih_database/108.csv
#   inflating: mit_dataset/mitbih_database/108annotations.txt
#   inflating: mit_dataset/mitbih_database/109.csv
#   inflating: mit_dataset/mitbih_database/109annotations.txt
#   inflating: mit_dataset/mitbih_database/111.csv
#   inflating: mit_dataset/mitbih_database/111annotations.txt
#   inflating: mit_dataset/mitbih_database/112.csv
#   inflating: mit_dataset/mitbih_database/112annotations.txt
#   inflating: mit_dataset/mitbih_database/113.csv
#   inflating: mit_dataset/mitbih_database/113annotations.txt
#   inflating: mit_dataset/mitbih_database/114.csv
#   inflating: mit_dataset/mitbih_database/114annotations.txt
#   inflating: mit_dataset/mitbih_database/115.csv
#   inflating: mit_dataset/mitbih_database/115annotations.txt
#   inflating: mit_dataset/mitbih_database/116.csv
#   inflating: mit_dataset/mitbih_database/116annotations.txt
#   inflating: mit_dataset/mitbih_database/117.csv
#   inflating: mit_dataset/mitbih_database/117annotations.txt
#   inflating: mit_dataset/mitbih_database/118.csv
#   inflating: mit_dataset/mitbih_database/118annotations.txt
#   inflating: mit_dataset/mitbih_database/119.csv
#   inflating: mit_dataset/mitbih_database/119annotations.txt
#   inflating: mit_dataset/mitbih_database/121.csv
#   inflating: mit_dataset/mitbih_database/121annotations.txt
#   inflating: mit_dataset/mitbih_database/122.csv
#   inflating: mit_dataset/mitbih_database/122annotations.txt
#   inflating: mit_dataset/mitbih_database/123.csv
#   inflating: mit_dataset/mitbih_database/123annotations.txt
#   inflating: mit_dataset/mitbih_database/124.csv
#   inflating: mit_dataset/mitbih_database/124annotations.txt
#   inflating: mit_dataset/mitbih_database/200.csv
#   inflating: mit_dataset/mitbih_database/200annotations.txt
#   inflating: mit_dataset/mitbih_database/201.csv
#   inflating: mit_dataset/mitbih_database/201annotations.txt
#   inflating: mit_dataset/mitbih_database/202.csv
#   inflating: mit_dataset/mitbih_database/202annotations.txt
#   inflating: mit_dataset/mitbih_database/203.csv
#   inflating: mit_dataset/mitbih_database/203annotations.txt
#   inflating: mit_dataset/mitbih_database/205.csv
#   inflating: mit_dataset/mitbih_database/205annotations.txt
#   inflating: mit_dataset/mitbih_database/207.csv
#   inflating: mit_dataset/mitbih_database/207annotations.txt
#   inflating: mit_dataset/mitbih_database/208.csv
#   inflating: mit_dataset/mitbih_database/208annotations.txt
#   inflating: mit_dataset/mitbih_database/209.csv
#   inflating: mit_dataset/mitbih_database/209annotations.txt
#   inflating: mit_dataset/mitbih_database/210.csv
#   inflating: mit_dataset/mitbih_database/210annotations.txt
#   inflating: mit_dataset/mitbih_database/212.csv
#   inflating: mit_dataset/mitbih_database/212annotations.txt
#   inflating: mit_dataset/mitbih_database/213.csv
#   inflating: mit_dataset/mitbih_database/213annotations.txt
#   inflating: mit_dataset/mitbih_database/214.csv
#   inflating: mit_dataset/mitbih_database/214annotations.txt
#   inflating: mit_dataset/mitbih_database/215.csv
#   inflating: mit_dataset/mitbih_database/215annotations.txt
#   inflating: mit_dataset/mitbih_database/217.csv
#   inflating: mit_dataset/mitbih_database/217annotations.txt
#   inflating: mit_dataset/mitbih_database/219.csv
#   inflating: mit_dataset/mitbih_database/219annotations.txt
#   inflating: mit_dataset/mitbih_database/220.csv
#   inflating: mit_dataset/mitbih_database/220annotations.txt
#   inflating: mit_dataset/mitbih_database/221.csv
#   inflating: mit_dataset/mitbih_database/221annotations.txt
#   inflating: mit_dataset/mitbih_database/222.csv
#   inflating: mit_dataset/mitbih_database/222annotations.txt
#   inflating: mit_dataset/mitbih_database/223.csv
#   inflating: mit_dataset/mitbih_database/223annotations.txt
#   inflating: mit_dataset/mitbih_database/228.csv
#   inflating: mit_dataset/mitbih_database/228annotations.txt
#   inflating: mit_dataset/mitbih_database/230.csv
#   inflating: mit_dataset/mitbih_database/230annotations.txt
#   inflating: mit_dataset/mitbih_database/231.csv
#   inflating: mit_dataset/mitbih_database/231annotations.txt
#   inflating: mit_dataset/mitbih_database/232.csv
#   inflating: mit_dataset/mitbih_database/232annotations.txt
#   inflating: mit_dataset/mitbih_database/233.csv
#   inflating: mit_dataset/mitbih_database/233annotations.txt
#   inflating: mit_dataset/mitbih_database/234.csv
#   inflating: mit_dataset/mitbih_database/234annotations.txt
